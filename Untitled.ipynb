# %%
import pandas as pd
pd.set_option("display.max_rows",1000)    # or pd.options.display.max_rows=1000
pd.set_option("display.max_columns",20)   # or pd.options.display.max_columns=20 
pd.set_option('precision',7)
pd.set_option('large_repr', 'truncate')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from ggplot import *

stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) + \
        geom_line() + \
        ylab('Price (US$)') + \
        ggtitle('Auto Stocks: Adj Close') + \
        scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
    
# Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
fig = stock_plot.draw()
ax = fig.gca()
labels = ax.get_xticklabels() 
for label in labels: 
    label.set_rotation(270)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-7c8ddbc5aee5> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 from ggplot import *
#       4
#       5 stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) +         geom_line() +         ylab('Price (US$)') +         ggtitle('Auto Stocks: Adj Close') +         scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
#
# ImportError: No module named ggplot

# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.describe()
# Out:
#            ounces
# count   9.0000000
# mean    6.0555556
# std     2.8553069
# min     3.0000000
# 25%     4.0000000
# 50%     6.0000000
# 75%     7.5000000
# max    12.0000000

# %%
import matplotlib.pyplot as plt
from ggplot import *

stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) + \
        geom_line() + \
        ylab('Price (US$)') + \
        ggtitle('Auto Stocks: Adj Close') + \
        scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
    
# Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
fig = stock_plot.draw()
ax = fig.gca()
labels = ax.get_xticklabels() 
for label in labels: 
    label.set_rotation(270)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-ce2c82cf7874> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 from ggplot import *
#       3
#       4 stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) +         geom_line() +         ylab('Price (US$)') +         ggtitle('Auto Stocks: Adj Close') +         scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
#       5
#
# ImportError: No module named ggplot

# %%
pivoted = df_long.pivot(index='Date', columns='Stock', values='Price')
pivoted.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-22e48d68d47b> in <module>()
# ----> 1 pivoted = df_long.pivot(index='Date', columns='Stock', values='Price')
#       2 pivoted.head()
#
# NameError: name 'df_long' is not defined

# %%
from pandas_datareader import data as web
from datetime import datetime
import pandas as pd

stocks = {'tech':['GOOGL', 'MSFT', 'LNKD', 'YHOO', 'FB','HPQ','AMZN'],
          'auto':['TM','F','GM','HMC','NSANY','HYMTF'],
          'housing':['HD','WMT','LOW']
          }

start_date = datetime(2014,1,1)
end_date = datetime(2014, 11, 30)

def get_px(stock, start, end):
    return web.get_data_yahoo(stock, start, end)['Adj Close']

df = pd.DataFrame({n: get_px(n, start_date, end_date) for n in stocks['tech']})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-d1a58b0c3ae1> in <module>()
# ----> 1 from pandas_datareader import data as web
#       2 from datetime import datetime
#       3 import pandas as pd
#       4
#       5 stocks = {'tech':['GOOGL', 'MSFT', 'LNKD', 'YHOO', 'FB','HPQ','AMZN'],
#
# ImportError: No module named pandas_datareader

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_excel('C:\gantt chart.xlsx', sheetname='Sheet1')
df.hist(column='Task', by='slack')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-9cbf23e04ede> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 import seaborn as sns
#       5
#       6 df = pd.read_excel('/home/pybokeh/Downloads/temp.xlsx', sheetname='Claims')
#
# ImportError: No module named seaborn

# %%
import matplotlib.pyplot as plt
from ggplot import *

stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) + \
        geom_line() + \
        ylab('Price (US$)') + \
        ggtitle('Auto Stocks: Adj Close') + \
        scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
    
# Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
fig = stock_plot.draw()
ax = fig.gca()
labels = ax.get_xticklabels() 
for label in labels: 
    label.set_rotation(270)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ce2c82cf7874> in <module>()
#       2 from ggplot import *
#       3
# ----> 4 stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) +         geom_line() +         ylab('Price (US$)') +         ggtitle('Auto Stocks: Adj Close') +         scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
#       5
#       6 # Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
#
# NameError: name 'df_long' is not defined

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})

df.assign(ratio = df['data1'] / df['data2'])
# Out:
#        data1      data2      ratio
# 0  1.3649825 -0.2435346 -5.6048820
# 1  1.1153136  1.4414884  0.7737236
# 2 -1.3481306 -0.1904195  7.0797941
# 3 -1.8901188  0.3228232 -5.8549650
# 4  1.3639192  1.1611244  1.1746539

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_excel('C:\gantt chart.xlsx', sheetname='Sheet1')
df.hist(column='Task', by='slack')
plt.show()

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({"var1":[1,2,3,4,5,6], "var2":[1,2,3,4,5,6]})
plt.plot(df["var1"], df["var2"])
plt.show()

# %%
plt.plot("var1", "var2", data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
from ggplot import *

stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) + \
        geom_line() + \
        ylab('Price (US$)') + \
        ggtitle('Auto Stocks: Adj Close') + \
        scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
    
# Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
fig = stock_plot.draw()
ax = fig.gca()
labels = ax.get_xticklabels() 
for label in labels: 
    label.set_rotation(270)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ce2c82cf7874> in <module>()
#       2 from ggplot import *
#       3
# ----> 4 stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) +         geom_line() +         ylab('Price (US$)') +         ggtitle('Auto Stocks: Adj Close') +         scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
#       5
#       6 # Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
#
# NameError: name 'df_long' is not defined

# %%
df.hist(column='Task', by='slack')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-2be4a993072e> in <module>()
# ----> 1 df.hist(column='Task', by='slack')
#       2 plt.show()
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\tools\plotting.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2879                             layout=layout, bins=bins, xlabelsize=xlabelsize,
#    2880                             xrot=xrot, ylabelsize=ylabelsize,
# -> 2881                             yrot=yrot, **kwds)
#    2882         return axes
#    2883
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\tools\plotting.py in grouped_hist(data, column, by, ax, bins, figsize, layout, sharex, sharey, rot, grid, xlabelsize, xrot, ylabelsize, yrot, **kwargs)
# ...

# %%
df.boxplot(column='Task', by='slack')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-8386b2cd37e0> in <module>()
# ----> 1 df.boxplot(column='Task', by='slack')
#       2 plt.show()
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5579     ax = plots.boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5580                        grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5581                        return_type=return_type, **kwds)
#    5582     plt.draw_if_interactive()
#    5583     return ax
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\tools\plotting.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2745                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_excel('C:\gantt chart.xlsx', sheetname='Sheet1')
df.hist(column='Task', by='slack')
plt.show()

# %%
df.boxplot(column='Task', by='slack')
plt.show()

# %%
from pandas_datareader import data as web
from datetime import datetime
import pandas as pd

stocks = {'tech':['GOOGL', 'MSFT', 'LNKD', 'YHOO', 'FB','HPQ','AMZN'],
          'auto':['TM','F','GM','HMC','NSANY','HYMTF'],
          'housing':['HD','WMT','LOW']
          }

start_date = datetime(2014,1,1)
end_date = datetime(2014, 11, 30)

def get_px(stock, start, end):
    return web.get_data_yahoo(stock, start, end)['Adj Close']

df = pd.DataFrame({n: get_px(n, start_date, end_date) for n in stocks['tech']})

# %%
from pandas_datareader import data as web
from datetime import datetime
import pandas as pd

stocks = {'tech':['GOOGL', 'MSFT', 'LNKD', 'YHOO', 'FB','HPQ','AMZN'],
          'auto':['TM','F','GM','HMC','NSANY','HYMTF'],
          'housing':['HD','WMT','LOW']
          }

start_date = datetime(2014,1,1)
end_date = datetime(2014, 11, 30)

def get_px(stock, start, end):
    return web.get_data_yahoo(stock, start, end)['Adj Close']

df = pd.DataFrame({n: get_px(n, start_date, end_date) for n in stocks['tech']})

# %%
df.head(10)
# Out:
#                   AMZN         FB       GOOGL        HPQ        LNKD  \
# Date
# 2014-01-02  397.970001  54.709999  557.117134  11.570826  207.639999
# 2014-01-03  396.440002  54.560001  553.053047  11.855286  207.419998
# 2014-01-06  393.630005  57.200001  559.219245  11.834370  203.919998
# 2014-01-07  398.029999  57.919998  570.000007  11.788354  209.639999
# 2014-01-08  401.920013  58.230000  571.186165  11.482979  209.059998
# 2014-01-09  401.010010  57.220001  565.685676  11.549910  215.250000
# 2014-01-10  397.660004  57.939999  565.655647  11.587559  218.750000
# 2014-01-13  390.980011  55.910000  562.052070  11.763255  213.539993
# 2014-01-14  397.540009  57.740002  575.275276  12.068631  216.220001
# 2014-01-15  395.869995  57.599998  574.884895  12.064448  216.000000
#
#                  MSFT       YHOO
# Date
# 2014-01-02  34.270616  39.590000
# 2014-01-03  34.040055  40.119999
# 2014-01-06  33.320705  39.930000
# 2014-01-07  33.578933  40.919998
# ...

# %%
df.reset_index(level=0, inplace=True)
df.head(10)
# Out:
#         Date        AMZN         FB       GOOGL        HPQ        LNKD  \
# 0 2014-01-02  397.970001  54.709999  557.117134  11.570826  207.639999
# 1 2014-01-03  396.440002  54.560001  553.053047  11.855286  207.419998
# 2 2014-01-06  393.630005  57.200001  559.219245  11.834370  203.919998
# 3 2014-01-07  398.029999  57.919998  570.000007  11.788354  209.639999
# 4 2014-01-08  401.920013  58.230000  571.186165  11.482979  209.059998
# 5 2014-01-09  401.010010  57.220001  565.685676  11.549910  215.250000
# 6 2014-01-10  397.660004  57.939999  565.655647  11.587559  218.750000
# 7 2014-01-13  390.980011  55.910000  562.052070  11.763255  213.539993
# 8 2014-01-14  397.540009  57.740002  575.275276  12.068631  216.220001
# 9 2014-01-15  395.869995  57.599998  574.884895  12.064448  216.000000
#
#         MSFT       YHOO
# 0  34.270616  39.590000
# 1  34.040055  40.119999
# 2  33.320705  39.930000
# 3  33.578933  40.919998
# 4  32.979472  41.020000
# 5  32.767356  40.919998
# ...

# %%
df_long = pd.melt(df, id_vars=['Date']).dropna()
df_long.head()
# Out:
#         Date variable       value
# 0 2014-01-02     AMZN  397.970001
# 1 2014-01-03     AMZN  396.440002
# 2 2014-01-06     AMZN  393.630005
# 3 2014-01-07     AMZN  398.029999
# 4 2014-01-08     AMZN  401.920013

# %%
df_long.tail()
# Out:
#            Date variable      value
# 1605 2014-11-21     YHOO  51.040001
# 1606 2014-11-24     YHOO  51.830002
# 1607 2014-11-25     YHOO  51.720001
# 1608 2014-11-26     YHOO  51.930000
# 1609 2014-11-28     YHOO  51.740002

# %%
df_long.rename(columns={'variable': 'Stock', 'value':'Price'},inplace=True)
df_long.head(10)
# Out:
#         Date Stock       Price
# 0 2014-01-02  AMZN  397.970001
# 1 2014-01-03  AMZN  396.440002
# 2 2014-01-06  AMZN  393.630005
# 3 2014-01-07  AMZN  398.029999
# 4 2014-01-08  AMZN  401.920013
# 5 2014-01-09  AMZN  401.010010
# 6 2014-01-10  AMZN  397.660004
# 7 2014-01-13  AMZN  390.980011
# 8 2014-01-14  AMZN  397.540009
# 9 2014-01-15  AMZN  395.869995

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from ggplot import *

stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) + \
        geom_line() + \
        ylab('Price (US$)') + \
        ggtitle('Auto Stocks: Adj Close') + \
        scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
    
# Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
fig = stock_plot.draw()
ax = fig.gca()
labels = ax.get_xticklabels() 
for label in labels: 
    label.set_rotation(270)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-7c8ddbc5aee5> in <module>()
#       6
#       7 # Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
# ----> 8 fig = stock_plot.draw()
#       9 ax = fig.gca()
#      10 labels = ax.get_xticklabels()
#
# AttributeError: 'ggplot' object has no attribute 'draw'

# %%
from graphics import *

class DieViewGreen:
    """ DieView is a widget that displays a graphical representation
    of a standard six-sided die."""

    def __init__(self, win, center, value):
        """Create a view of a die, e.g.:
           d1 = GDie(myWin, Point(40,50), 20)
        creates a die centered at (40,50) having sides
        of length 20."""

        # first define some standard values
        self.win = win
        #self.background = Color color of die face
        #self.foreground = Color2 # color of the pips

        # create a square for the face
        if value==0:
            x, y = center.getX(), center.getY()
            p1 = Point(x-25, y-25)
            p2 = Point(x+25, y+25)
            rect = Rectangle(p1,p2)
            rect.draw(win)
            rect.setFill('green')        

        """ Set this die to display value."""
        if value == 1:
            x, y = center.getX(), center.getY()
            p1 = Point(x-25, y-25)
            p2 = Point(x+25, y+25)
            rect = Rectangle(p1,p2)
            rect.draw(win)
            rect.setFill('green') 
            self.Brain=Text(Point(40,75),'B')
            self.Brain.draw(self.win)


        elif value == 2:
            x, y = center.getX(), center.getY()
            p1 = Point(x-25, y-25)
            p2 = Point(x+25, y+25)
            rect = Rectangle(p1,p2)
            rect.draw(win)
            rect.setFill('green') 
            self.Brain=Text(Point(40,75),'B')
            self.Brain.draw(self.win)

        elif value == 3:
            x, y = center.getX(), center.getY()
            p1 = Point(x-25, y-25)
            p2 = Point(x+25, y+25)
            rect = Rectangle(p1,p2)
            rect.draw(win)
            rect.setFill('green') 
            self.Brain=Text(Point(40,75),'B')
            self.Brain.draw(self.win)


        elif value == 4:
            x, y = center.getX(), center.getY()
            p1 = Point(x-25, y-25)
            p2 = Point(x+25, y+25)
            rect = Rectangle(p1,p2)
            rect.draw(win)
            rect.setFill('green') 
            self.Foot=Text(Point(40,75),'F')
            self.Foot.draw(self.win)


        elif value == 5:
            x, y = center.getX(), center.getY()
            p1 = Point(x-25, y-25)
            p2 = Point(x+25, y+25)
            rect = Rectangle(p1,p2)
            rect.draw(win)
            rect.setFill('green') 
            self.Foot=Text(Point(40,75),'F')
            self.Foot.draw(self.win)


        else:
            x, y = center.getX(), center.getY()
            p1 = Point(x-25, y-25)
            p2 = Point(x+25, y+25)
            rect = Rectangle(p1,p2)
            rect.draw(win)
            rect.setFill('green') 
            self.Shotgun=Text(Point(40,75),'S')
            self.Shotgun.draw(self.win)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-51120fb99c40> in <module>()
# ----> 1 from graphics import *
#       2
#       3 class DieViewGreen:
#       4     """ DieView is a widget that displays a graphical representation
#       5     of a standard six-sided die."""
#
# ImportError: No module named graphics

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from ggplot import *

stock_plot = ggplot(df_long, aes(x='Date', y='Price', color='Stock')) + \
        geom_line() + \
        ylab('Price (US$)') + \
        ggtitle('Auto Stocks: Adj Close') + \
        scale_x_date(labels='%b %d %y',breaks=date_breaks('3 months') )
    
# Have to use MATPLOTLIB api to rotate x tick labels.  Hopefully some day, ggplot will implement a rotation option.
fig = stock_plot.make()

# %%
from pandas_datareader import data as web
from datetime import datetime
import pandas as pd

stocks = {'tech':['GOOGL', 'MSFT', 'LNKD', 'YHOO', 'FB','HPQ','AMZN'],
          'auto':['TM','F','GM','HMC','NSANY','HYMTF'],
          'housing':['HD','WMT','LOW']
          }

start_date = datetime(2016,1,1)
end_date = datetime(2016, 11, 30)

def get_px(stock, start, end):
    return web.get_data_yahoo(stock, start, end)['Adj Close']

df = pd.DataFrame({n: get_px(n, start_date, end_date) for n in stocks['tech']})

# %%
df.head(10)
# Out:
#                   AMZN          FB       GOOGL        HPQ        LNKD  \
# Date
# 2016-01-04  636.989990  102.220001  759.440002  11.170854  225.550003
# 2016-01-05  633.789978  102.730003  761.530029  11.276784  229.000000
# 2016-01-06  632.650024  102.970001  759.330017  10.872322  226.080002
# 2016-01-07  607.940002   97.919998  741.000000  10.371560  217.000000
# 2016-01-08  607.049988   97.330002  730.909973  10.188588  215.899994
# 2016-01-11  617.739990   97.510002  733.070007  10.255999  210.929993
# 2016-01-12  617.890015   99.370003  745.340027  10.419709  210.429993
# 2016-01-13  581.809998   95.440002  719.570007  10.188588  203.130005
# 2016-01-14  593.000000   98.370003  731.390015  10.227109  203.210007
# 2016-01-15  570.179993   94.970001  710.489990   9.735976  196.320007
#
#                  MSFT       YHOO
# Date
# 2016-01-04  53.336436  31.400000
# 2016-01-05  53.579760  32.200001
# 2016-01-06  52.606467  32.160000
# 2016-01-07  50.776676  30.160000
# ...

# %%
df.tail(100)
# Out:
#                   AMZN          FB       GOOGL        HPQ        LNKD  \
# Date
# 2016-07-12  748.210022  117.930000  732.510010  13.484466  190.300003
# 2016-07-13  742.630005  116.779999  729.479980  13.572921  189.860001
# 2016-07-14  741.200012  117.290001  735.799988  13.563093  189.309998
# 2016-07-15  735.440002  116.860001  735.630005  13.612235  189.570007
# 2016-07-18  736.070007  119.370003  753.200012  13.700689  189.600006
# 2016-07-19  739.950012  120.610001  753.409973  13.808801  189.860001
# 2016-07-20  745.719971  121.919998  757.080017  13.916912  189.550003
# 2016-07-21  744.429993  120.610001  754.409973  13.759659  189.570007
# 2016-07-22  744.859985  121.000000  759.280029  13.867770  189.949997
# 2016-07-25  739.609985  121.629997  757.520020  13.916912  191.940002
# 2016-07-26  735.590027  121.220001  757.650024  13.936569  192.550003
# 2016-07-27  736.669983  123.339996  761.969971  13.749830  192.300003
# ...

# %%
plt.show()

# %%
df.boxplot(column='GOOGL',by='Date')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-78e4744b1594> in <module>()
# ----> 1 df.boxplot(column='GOOGL',by='Date')
#       2 plt.show()
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5579     ax = plots.boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5580                        grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5581                        return_type=return_type, **kwds)
#    5582     plt.draw_if_interactive()
#    5583     return ax
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\tools\plotting.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2745                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
import pandas as pd    

with open('C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat','r') as f:
    next(f) # skip first row
    df = pd.DataFrame(l.rstrip().split() for l in f)

print(df)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-36-930c5f6a4b54> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 with open('C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat','r') as f:
#       4     next(f) # skip first row
#       5     df = pd.DataFrame(l.rstrip().split() for l in f)
#
# IOError: [Errno 2] No such file or directory: 'C:\\Users\\Sonu\\Downloads\\ml-1m\\ml-1m\\user.dat'

# %%
df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat', sep='\s+', header=None, skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-37-c86b32a4d6d4> in <module>()
# ----> 1 df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat', sep='\s+', header=None, skiprows=1)
#
# ...

# %%
df = pd.read_csv('~\C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat', sep='\s+', header=None, skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-38-72900133b38f> in <module>()
# ----> 1 df = pd.read_csv('~\C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat', sep='\s+', header=None, skiprows=1)
#
# ...

# %%
df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.dat', sep='\s+', header=None, skiprows=1)

# %%
df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\movies.dat', sep='\s+', header=None, skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-40-8213a032f88e> in <module>()
# ----> 1 df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\movies.dat', sep='\s+', header=None, skiprows=1)
#
# ...

# %%
df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat', sep='\s+', header=None, skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-41-c86b32a4d6d4> in <module>()
# ----> 1 df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\user.dat', sep='\s+', header=None, skiprows=1)
#
# ...

# %%
df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.dat', sep='\s+', header=None, skiprows=1)

# %%
df.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-bcce0791febf> in <module>()
# ----> 1 df.read()
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'read'

# %%
df.head(10)
# Out:
#                      0
# 0  2::M::56::16::70072
# 1  3::M::25::15::55117
# 2   4::M::45::7::02460
# 3  5::M::25::20::55455
# 4   6::F::50::9::55117
# 5   7::M::35::1::06810
# 6  8::M::25::12::11413
# 7  9::M::25::17::61614
# 8  10::F::35::1::95370
# 9  11::F::25::1::04093

# %%
import pandas as pd    

with open('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.dat,'r') as f:
    next(f) # skip first row
    df = pd.DataFrame(l.rstrip().split() for l in f)

print(df)
# Out:
#   File "<ipython-input-45-93deabecf028>", line 3
#     with open('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.dat,'r') as f:
#                                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.dat', sep='\s+', header=None, skiprows=0
# Out:
#   File "<ipython-input-46-7e9e17f989b3>", line 1
#     df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.dat', sep='\s+', header=None, skiprows=0
#                                                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
df = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.dat', sep='\s+', header=None, skiprows=0)

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-3106d06b6e49> in <module>()
# ----> 1 df.show()
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.head(100)
# Out:
#                         0
# 0      1::F::1::10::48067
# 1     2::M::56::16::70072
# 2     3::M::25::15::55117
# 3      4::M::45::7::02460
# 4     5::M::25::20::55455
# 5      6::F::50::9::55117
# 6      7::M::35::1::06810
# 7     8::M::25::12::11413
# 8     9::M::25::17::61614
# 9     10::F::35::1::95370
# 10    11::F::25::1::04093
# 11   12::M::25::12::32793
# 12    13::M::45::1::93304
# 13    14::M::35::0::60126
# 14    15::M::25::7::22903
# 15    16::F::35::0::20670
# 16    17::M::50::1::95350
# 17    18::F::18::3::95825
# 18    19::M::1::10::48073
# 19   20::M::25::14::55113
# 20   21::M::18::16::99353
# 21   22::M::18::15::53706
# 22    23::M::35::0::90049
# 23    24::F::25::7::10023
# 24    25::M::18::4::01609
# 25    26::M::25::7::23112
# 26   27::M::25::11::19130
# 27    28::F::25::1::14607
# 28    29::M::35::7::33407
# 29    30::F::35::7::19143
# 30    31::M::56::7::06840
# 31    32::F::25::0::19355
# 32    33::M::45::3::55421
# 33    34::F::18::0::02135
# ...

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('ml-100k/u.user', sep='|', names=u_cols,
                    encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-54-4ca5d82917fb> in <module>()
#       1 u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
#       2 users = pd.read_csv('ml-100k/u.user', sep='|', names=u_cols,
# ----> 3                     encoding='latin-1')
#
# ...

# %%
from_csv = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.csv')
from_csv.head()
# Out:
#     1::F::1::10::48067
# 0  2::M::56::16::70072
# 1  3::M::25::15::55117
# 2   4::M::45::7::02460
# 3  5::M::25::20::55455
# 4   6::F::50::9::55117

# %%
# !head -n 5 C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.csv
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.csv', sep='::', header=None)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#          0  1   2   3           4
# 0        1  F   1  10       48067
# 1        2  M  56  16       70072
# 2        3  M  25  15       55117
# 3        4  M  45   7       02460
# 4        5  M  25  20       55455
# 5        6  F  50   9       55117
# 6        7  M  35   1       06810
# 7        8  M  25  12       11413
# 8        9  M  25  17       61614
# 9       10  F  35   1       95370
# 10      11  F  25   1       04093
# 11      12  M  25  12       32793
# 12      13  M  45   1       93304
# 13      14  M  35   0       60126
# 14      15  M  25   7       22903
# 15      16  F  35   0       20670
# 16      17  M  50   1       95350
# ...

# %%
import pandas as pd

pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\ratings.csv', sep='::', header=None)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-60-4295b98c1d8e> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\ratings.csv', sep='::', header=None)
#
# ...

# %%
import pandas as pdd

pdd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\users.csv', sep='::', header=None)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#          0  1   2   3           4
# 0        1  F   1  10       48067
# 1        2  M  56  16       70072
# 2        3  M  25  15       55117
# 3        4  M  45   7       02460
# 4        5  M  25  20       55455
# 5        6  F  50   9       55117
# 6        7  M  35   1       06810
# 7        8  M  25  12       11413
# 8        9  M  25  17       61614
# 9       10  F  35   1       95370
# 10      11  F  25   1       04093
# 11      12  M  25  12       32793
# 12      13  M  45   1       93304
# 13      14  M  35   0       60126
# 14      15  M  25   7       22903
# 15      16  F  35   0       20670
# 16      17  M  50   1       95350
# ...

# %%
import pandas as pd

pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\ratings.csv', sep='::', header=None)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-62-4295b98c1d8e> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ml-1m\ratings.csv', sep='::', header=None)
#
# ...

# %%
import pandas as pd

pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\users.dat', sep='::', header=None)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#          0  1   2   3           4
# 0        1  F   1  10       48067
# 1        2  M  56  16       70072
# 2        3  M  25  15       55117
# 3        4  M  45   7       02460
# 4        5  M  25  20       55455
# 5        6  F  50   9       55117
# 6        7  M  35   1       06810
# 7        8  M  25  12       11413
# 8        9  M  25  17       61614
# 9       10  F  35   1       95370
# 10      11  F  25   1       04093
# 11      12  M  25  12       32793
# 12      13  M  45   1       93304
# 13      14  M  35   0       60126
# 14      15  M  25   7       22903
# 15      16  F  35   0       20670
# 16      17  M  50   1       95350
# 17      18  F  18   3       95825
# ...

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-3106d06b6e49> in <module>()
# ----> 1 df.show()
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.head()
# Out:
#    0  1   2   3      4
# 0  1  F   1  10  48067
# 1  2  M  56  16  70072
# 2  3  M  25  15  55117
# 3  4  M  45   7  02460
# 4  5  M  25  20  55455

# %%
import pandas as pd
pd.u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\users.dat', sep='|', names=u_cols,
                    encoding='latin-1')

pd.r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ratings.dat', sep='\t', names=r_cols,
                      encoding='latin-1')


pd.m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\movies.dat', sep='|', names=m_cols, usecols=range(5),
                     encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-71-aad1e998fbb5> in <module>()
#       6 pd.r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
#       7 ratings = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\ratings.dat', sep='\t', names=r_cols,
# ----> 8                       encoding='latin-1')
#       9
#      10
#
# ...

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('ml-100k/u.user', sep='|', names=u_cols,
                    encoding='latin-1')

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('ml-100k/u.data', sep='\t', names=r_cols,
                      encoding='latin-1')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('ml-100k/u.item', sep='|', names=m_cols, usecols=range(5),
                     encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-72-1c7347bb3bac> in <module>()
#       1 u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
#       2 users = pd.read_csv('ml-100k/u.user', sep='|', names=u_cols,
# ----> 3                     encoding='latin-1')
#       4
#       5 r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
#
# ...

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.user', sep='::+|', names=u_cols,
                    encoding='latin-1')

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.data', sep='::+|', names=r_cols,
                      encoding='latin-1')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.item', sep='::+|', names=m_cols, usecols=range(5),
                     encoding='latin-1')

# create one merged DataFrame
movie_ratings = pd.merge(movies, ratings)
lens = pd.merge(movie_ratings, users)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
most_rated = lens.groupby('title').size().sort_values(ascending=False)[:25]
most_rated
# Out:
# Series([], dtype: int64)

# %%
movie_ratings
# Out:
# Empty DataFrame
# Columns: [movie_id, title, release_date, video_release_date, imdb_url, user_id, rating, unix_timestamp]
# Index: []

# %%
movies
# Out:
#                                                movie_id        title  \
# 0                        1::Toy Story (1995)::Animation   Children's
# 1                          2::Jumanji (1995)::Adventure   Children's
# 2                    3::Grumpier Old Men (1995)::Comedy      Romance
# 3                   4::Waiting to Exhale (1995)::Comedy        Drama
# 4         5::Father of the Bride Part II (1995)::Comedy          NaN
# 5                                6::Heat (1995)::Action        Crime
# 6                             7::Sabrina (1995)::Comedy      Romance
# 7                     8::Tom and Huck (1995)::Adventure   Children's
# 8                        9::Sudden Death (1995)::Action          NaN
# 9                          10::GoldenEye (1995)::Action    Adventure
# 10           11::American President, The (1995)::Comedy        Drama
# 11       12::Dracula: Dead and Loving It (1995)::Comedy       Horror
# 12                          13::Balto (1995)::Animation   Children's
# ...

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.user', sep='::', names=u_cols,
                    encoding='latin-1')

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.data', sep='::\t|', names=r_cols,
                      encoding='latin-1')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.item', sep='::', names=m_cols, usecols=range(5),
                     encoding='latin-1')

# create one merged DataFrame
movie_ratings = pd.merge(movies, ratings)
lens = pd.merge(movie_ratings, users)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-472433eae2ca> in <module>()
#       5 r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
# ...

# %%
movies
# Out:
#       movie_id                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.user', sep='::', names=u_cols,
                    encoding='latin-1')

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.data', sep='::\t|', names=r_cols,
                      encoding='latin-1')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('C:\Users\Sonu\Downloads\ml-1m\u.item', sep='::', names=m_cols, usecols=range(5),
                     encoding='latin-1')

# create one merged DataFrame
movie_ratings = pd.merge(movies, ratings)
lens = pd.merge(movie_ratings, users)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-472433eae2ca> in <module>()
#       5 r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
# ...

# %%
movie_ratings

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('C:/Users/Sonu/Downloads/ml-1m/users.dat', sep='::')

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('C:/Users/Sonu/Downloads/ml-1m/ratings.dat', sep='::\t|')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('C:/Users/Sonu/Downloads/ml-1m/movies.dat', sep='::')

# create one merged DataFrame
movie_ratings = pd.merge(movies, ratings)
lens = pd.merge(movie_ratings, users)
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ...

# %% [markdown]
# genes = np.loadtxt("genes.csv", delimiter=",", dtype=[('gene', '|S10'), ('value', '<f4')])

# %%
genes = np.loadtxt("genes.csv", delimiter=",", dtype=[('gene', '|S10'), ('value', '<f4')])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-89-b6e26b524c69> in <module>()
# ----> 1 genes = np.loadtxt("genes.csv", delimiter=",", dtype=[('gene', '|S10'), ('value', '<f4')])
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     801                 fh = iter(bz2.BZ2File(fname))
#     802             elif sys.version_info[0] == 2:
# --> 803                 fh = iter(open(fname, 'U'))
#     804             else:
#     805                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: 'genes.csv'

# %%
genes = np.loadtxt("C:/Users/Sonu/Downloads/ml-1m/movies.dat", delimiter="::", dtype=[('gene', '|S10'), ('value', '<f4')])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-b64262010185> in <module>()
# ----> 1 genes = np.loadtxt("C:/Users/Sonu/Downloads/ml-1m/movies.dat", delimiter="::", dtype=[('gene', '|S10'), ('value', '<f4')])
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
# ...

# %%
genes = np.loadtxt("C:/Users/Sonu/Downloads/ml-1m/movies.dat", delimiter="::")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-33f022c0a834> in <module>()
# ----> 1 genes = np.loadtxt("C:/Users/Sonu/Downloads/ml-1m/movies.dat", delimiter="::")
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('C:/Users/Sonu/Downloads/ml-1m/users.dat', sep='::')

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('C:/Users/Sonu/Downloads/ml-1m/ratings.dat', sep='::\t|')

# the movies file contains columns indicating the movie's genres
# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('C:/Users/Sonu/Downloads/ml-1m/movies.dat', sep='::')

# create one merged DataFrame
movie_ratings = pd.merge(movies, ratings)
lens = pd.merge(movie_ratings, users)
